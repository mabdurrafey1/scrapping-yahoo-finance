# %% [markdown]
# <a href="https://colab.research.google.com/github/mabdurrafey1/scrapping-yahoo-finance/blob/main/scraping_yahoo_finance_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade gspread
# !pip install kora -q
from kora.selenium import wd 
import threading
import multiprocessing
import os
import urllib3
# import pandas as pd
from datetime import datetime
from google.colab import auth
auth.authenticate_user()

import gspread
from oauth2client.client import GoogleCredentials

gc = gspread.authorize(GoogleCredentials.get_application_default())


 
# ws=wb.worksheet("mywork")
# data=ws.get_all_values()
# length=len(data)
# lengthWs=0
# symbols_ws=wb.worksheet("listofSymbols")
# symbols_data=symbols_ws.get_all_values()
# datetoday = datetime.now().strftime("%Y-%m-%d")
# includes=-1
# for i in range(length):
#   if data[i][0]=='' or data[i][0]==datetoday:
#     lengthWs=i
#     includes=1
#     break
# print(lengthWs)
# ws.update_cell(lengthWs+1+1,1,datetoday)
# if includes==-1:
#   lengthWs=lengthWs+1

# def getMarketData(symbol,exchange,row):
#   print(symbol,exchange,row,"\n")
#   import time
#   marketUrl='https://finance.yahoo.com/quote/'+symbol+"/"
#   print(marketUrl,)
#   wd.get(marketUrl)
#   time.sleep(1)
#   try:
#     wd.find_element_by_xpath("/html/body/div[1]/div/div/div/form/div[2]/div[2]/button").click()
#     pass
#   except:
#     pass
#   # print(wd.page_source)
#   # wd.save_screenshot(symbol+".png")
#   try:
#     wd.get(marketUrl)
#     time.sleep(1)
#     # wd.save_screenshot(symbol+".png")
#     market=wd.find_element_by_xpath("/html/body/div[1]/div/div/div[1]/div/div[2]/div/div/div[4]/div/div/div/div[3]/div[1]/p/span[1]").text
#   except:
#     try:
#       print("checking again!")
#       wd.get(marketUrl)
#       time.sleep(1)
#       market=wd.find_element_by_xpath("/html/body/div[1]/div/div/div[1]/div/div[2]/div/div/div[4]/div/div/div/div[3]/div[1]/p/span[1]").text
#       # wd.save_screenshot(symbol+".png")
#     except:
#       print("no market data found")
#       wd.save_screenshot(symbol+".png")
#       prvCLS=wd.find_element_by_xpath("/html/body/div[1]/div/div/div[1]/div/div[3]/div[1]/div/div[1]/div/div/div/div[2]/div[1]/table/tbody/tr[1]/td[2]/span").text
#       print("PVRCLS",prvCLS)    
#       # volume=wd.find_element_by_xpath("/html/body/div[5]/div[2]/div[5]/mw-rangebar[1]/div[1]/span[1]").text
#       volume=wd.find_element_by_xpath("//*[@id='quote-summary']/div[1]/table/tbody/tr[7]/td[2]/span").text
#       print("Volume",volume)
#       range=wd.find_element_by_xpath("//*[@id='quote-summary']/div[1]/table/tbody/tr[5]/td[2]").text
#       print("RANGE",range)
#       # dayVol=wd.find_element_by_xpath("/html/body/div[4]/div[6]/div[1]/div[1]/div/ul/li[16]/span[1]").text
#       dayOpenOrClose=wd.find_element_by_xpath("//*[@id='quote-header-info']/div[3]/div[1]/div/span[1]").text
#       print("dayOpenOrClose",dayOpenOrClose)
#       openOrClose=wd.find_element_by_xpath("//*[@id='quote-market-notice']/span").text
#       print("openOrClose",openOrClose)
#       # dayClose=wd.find_element_by_xpath("/html/body/div[4]/div[2]/div[3]/div/div[4]/table/tbody/tr/td[1]").text
#       dayOpen=wd.find_element_by_xpath("//*[@id='quote-summary']/div[1]/table/tbody/tr[2]/td[2]/span").text
#       print("dayOpen",dayOpen)
#       yearly=wd.find_element_by_xpath("/html/body/div[1]/div/div/div[1]/div/div[3]/div[1]/div/div[1]/div/div/div/div[2]/div[1]/table/tbody/tr[6]/td[2]").text
#       print("yearly",yearly)
#       yearHigh=yearly.split("-")[1]
#       print("yearHigh",yearHigh)
#       yearLow=yearly.split("-")[0]
#       print("yearLow",yearLow)
#       upperRange=range.split("-")[1]
#       print("Upper Range",upperRange)
#       lowerRange=range.split("-")[0]
#       print("Lower Range",lowerRange)
#       # wdriver.quit()
#       ws.update_cell(row,1,datetoday)
#       ws.update_cell(row,2,exchange)
#       ws.update_cell(row,3,symbol)
#       # ws.update_cell(row,4,afterOrPre)
#       ws.update_cell(row,5,prvCLS)
#       ws.update_cell(row,6,dayOpen)
#       ws.update_cell(row,7,upperRange)
#       ws.update_cell(row,8,lowerRange)
#       ws.update_cell(row,9,dayOpenOrClose)
#       ws.update_cell(row,10,volume)
#       ws.update_cell(row,4,"OPEN or CLOSED")
#       ws.update_cell(row,17,yearHigh)
#       ws.update_cell(row,18,yearLow)
#       print("no data found")
#       return
  
#   if market:
#     print("market",market)
#     ws.update_cell(row,8,market)
#     # date=wd.find_element_by_xpath("/html/body/div[4]/div[2]/div[3]/div/div[1]/span/bg-quote").text
#     # print(date)
#     value=wd.find_element_by_xpath("//*[@id='quote-header-info']/div[3]/div[1]/p/span[1]").text
#     afterOrPre=wd.find_element_by_xpath("//*[@id='quote-header-info']/div[3]/div[1]/p/span[3]/span").text
#     print("Value",value)
#     prvCLS=wd.find_element_by_xpath("//*[@id='quote-header-info']/div[3]/div[1]/p/span[1]").text
#     print("PVRCLS",prvCLS)    
#     # volume=wd.find_element_by_xpath("/html/body/div[5]/div[2]/div[5]/mw-rangebar[1]/div[1]/span[1]").text
#     volume=wd.find_element_by_xpath("//*[@id='quote-summary']/div[1]/table/tbody/tr[7]/td[2]/span").text
#     print("Volume",volume)
#     range=wd.find_element_by_xpath("//*[@id='quote-summary']/div[1]/table/tbody/tr[5]/td[2]").text
#     print("RANGE",range)
#     # dayVol=wd.find_element_by_xpath("/html/body/div[4]/div[6]/div[1]/div[1]/div/ul/li[16]/span[1]").text
#     dayOpenOrClose=wd.find_element_by_xpath("//*[@id='quote-header-info']/div[3]/div[1]/div/span[1]").text
#     print("dayOpenOrClose",dayOpenOrClose)
#     openOrClose=wd.find_element_by_xpath("//*[@id='quote-market-notice']/span").text
#     print("openOrClose",openOrClose)
#     # dayClose=wd.find_element_by_xpath("/html/body/div[4]/div[2]/div[3]/div/div[4]/table/tbody/tr/td[1]").text
#     dayOpen=wd.find_element_by_xpath("//*[@id='quote-summary']/div[1]/table/tbody/tr[2]/td[2]/span").text
#     print("dayOpen",dayOpen)
#     yearly=wd.find_element_by_xpath("/html/body/div[1]/div/div/div[1]/div/div[3]/div[1]/div/div[1]/div/div/div/div[2]/div[1]/table/tbody/tr[6]/td[2]").text
#     print("yearly",yearly)
#     yearHigh=yearly.split("-")[1]
#     print("yearHigh",yearHigh)
#     yearLow=yearly.split("-")[0]
#     print("yearLow",yearLow)
#     upperRange=range.split("-")[1]
#     print("Upper Range",upperRange)
#     lowerRange=range.split("-")[0]
#     print("Lower Range",lowerRange)
#     # day=date.split(" ")[1].split(",")[0]
#     # month=date.split(" ")[0]
#     # year=date.split(" ")[2]
#     timetime=wd.find_element_by_xpath("/html/body/div[1]/div/div/div[1]/div/div[2]/div/div/div[4]/div/div/div/div[3]/div[1]/p/span[3]").text
#     print("timetime",timetime)
#     time=timetime.split(":")[1]+":"+timetime.split(":")[2]
#     print("time",time)
#     # time=date.split(" ")[3]+date.split(" ")[4]   
#     ws.update_cell(row,1,datetoday)
#     ws.update_cell(row,2,exchange)
#     ws.update_cell(row,3,symbol)
#     ws.update_cell(row,4,afterOrPre)
#     ws.update_cell(row,5,prvCLS)
#     ws.update_cell(row,6,dayOpen)
#     ws.update_cell(row,7,upperRange)
#     ws.update_cell(row,8,lowerRange)
#     ws.update_cell(row,9,dayOpenOrClose)
#     ws.update_cell(row,10,volume)
#     if  afterOrPre.find("Pre")!=-1:
#       print("pre data is writing")
#       ws.update_cell(row,11,value)
#       ws.update_cell(row,12,time)
#       # ws.update_cell(row,1,volume)
#     # elif data[row][11]:
#       print('has pre value')
#     # else:
#       # ws.update_cell(row,11,"No activity rigth now")
#     # print("market.find()",market.find("After"))
#     if afterOrPre.find("After")!=-1:
#       print("after data is writing")
#       ws.update_cell(row,14,value)
#       ws.update_cell(row,15,time)
#       # ws.update_cell(row,17,volume)
#     # elif data[row][15]:
#       # print(len(data))
#       # print("has post value")
#     # else:
#       # ws.update_cell(row,14,"No activity rigth now")

#     ws.update_cell(row,17,yearHigh)
#     ws.update_cell(row,18,yearLow)
  
#   # elif market=="OPEN":
#   #   ws.update_cell(row,8,market)
  

#   # else:
#   #   ws.update_cell(row,8,market)
#   #   print("Market is closed right now")

# def runBatch(s,e,l):
#   threadList=[]
#   for row in symbols_data[s:e]:
#     t=threading.Thread(target=getMarketData,args=(row[1],row[0],l+2,wd,))
#     l=l+1
#     threadList.append(t)
#     t.start()
#   for j in threadList:
#     j.join()
#     print("****************************finished")
#   return l


# # for i in range(0,len(symbols_data),100):
# #   print(i,i+10)
# #   print(lengthWs)
# #   lengthWs=runBatch(i,i+10,lengthWs)
# #   print(lengthWs)

# # runBatch(0,2,lengthWs)
# # runBatch(1,2,lengthWs)

# p1 = multiprocessing.Process(target=getMarketData, args=(symbols_data[0][1],symbols_data[0][0],lengthWs+1+1,))
# p2 = multiprocessing.Process(target=getMarketData, args=(symbols_data[1][1],symbols_data[1][0],lengthWs+1+1+1, ))

# p1.start()
# p2.start()

# p1.join()
# p2.join()

# print('Done')

# for i in range(0,len(symbols_data)-27):
#   # if i==0:
#   #  getAndWrite(symbols_data[i][1],symbols_data[i][0],lengthWs+1+1) 
#   # else:
#   getMarketData(symbols_data[i][1],symbols_data[i][0],lengthWs+1+1)
#   lengthWs=lengthWs+1

# /html/body/div[1]/div/div/div/form/div[2]/div[2]/button

# %%
wb = gc.open_by_key('1JirUWvVLQy9CgAd-TyHtl4hsKyAYbx4hcooSiz3zWTU')
ws=wb.worksheet("mywork")
data=ws.get_all_values()
length=len(data)
lengthWs=0
symbols_ws=wb.worksheet("listofSymbols")
symbols_data=symbols_ws.get_all_values()
datetoday = datetime.now().strftime("%Y-%m-%d")
includes=-1
for i in range(length):
  if data[i][0]=='' or data[i][0]==datetoday:
    lengthWs=i
    includes=1
    break
print(lengthWs)
ws.update_cell(lengthWs+1+1,1,datetoday)
if includes==-1:
  lengthWs=lengthWs+1

def getMarketData(symbol,exchange,row):
  print(symbol,exchange,row,"88888888888888888888888888\n")
  import time
  marketUrl='https://finance.yahoo.com/quote/'+symbol+"/"
  print(marketUrl,)
  wd.get(marketUrl)
  time.sleep(1)
  try:
    wd.find_element_by_xpath("/html/body/div[1]/div/div/div/form/div[2]/div[2]/button").click()
    pass
  except:
    pass
  # print(wd.page_source)
  # wd.save_screenshot(symbol+".png")
  try:
    wd.get(marketUrl)
    time.sleep(1)
    # wd.save_screenshot(symbol+".png")
    market=wd.find_element_by_xpath("/html/body/div[1]/div/div/div[1]/div/div[2]/div/div/div[4]/div/div/div/div[3]/div[1]/p/span[1]").text
  except:
    try:
      print("checking again!")
      wd.get(marketUrl)
      time.sleep(1)
      market=wd.find_element_by_xpath("/html/body/div[1]/div/div/div[1]/div/div[2]/div/div/div[4]/div/div/div/div[3]/div[1]/p/span[1]").text
      # wd.save_screenshot(symbol+".png")
    except:
      print("no market data found")
      wd.save_screenshot(symbol+".png")
      prvCLS=wd.find_element_by_xpath("/html/body/div[1]/div/div/div[1]/div/div[3]/div[1]/div/div[1]/div/div/div/div[2]/div[1]/table/tbody/tr[1]/td[2]/span").text
      print("PVRCLS",prvCLS)    
      # volume=wd.find_element_by_xpath("/html/body/div[5]/div[2]/div[5]/mw-rangebar[1]/div[1]/span[1]").text
      volume=wd.find_element_by_xpath("//*[@id='quote-summary']/div[1]/table/tbody/tr[7]/td[2]/span").text
      print("Volume",volume)
      range=wd.find_element_by_xpath("//*[@id='quote-summary']/div[1]/table/tbody/tr[5]/td[2]").text
      print("RANGE",range)
      # dayVol=wd.find_element_by_xpath("/html/body/div[4]/div[6]/div[1]/div[1]/div/ul/li[16]/span[1]").text
      dayOpenOrClose=wd.find_element_by_xpath("//*[@id='quote-header-info']/div[3]/div[1]/div/span[1]").text
      print("dayOpenOrClose",dayOpenOrClose)
      openOrClose=wd.find_element_by_xpath("//*[@id='quote-market-notice']/span").text
      print("openOrClose",openOrClose)
      # dayClose=wd.find_element_by_xpath("/html/body/div[4]/div[2]/div[3]/div/div[4]/table/tbody/tr/td[1]").text
      dayOpen=wd.find_element_by_xpath("//*[@id='quote-summary']/div[1]/table/tbody/tr[2]/td[2]/span").text
      print("dayOpen",dayOpen)
      yearly=wd.find_element_by_xpath("/html/body/div[1]/div/div/div[1]/div/div[3]/div[1]/div/div[1]/div/div/div/div[2]/div[1]/table/tbody/tr[6]/td[2]").text
      print("yearly",yearly)
      yearHigh=yearly.split("-")[1]
      print("yearHigh",yearHigh)
      yearLow=yearly.split("-")[0]
      print("yearLow",yearLow)
      upperRange=range.split("-")[1]
      print("Upper Range",upperRange)
      lowerRange=range.split("-")[0]
      print("Lower Range",lowerRange)
      # wdriver.quit()
      ws.update_cell(row,1,datetoday)
      ws.update_cell(row,2,exchange)
      ws.update_cell(row,3,symbol)
      # ws.update_cell(row,4,afterOrPre)
      ws.update_cell(row,5,prvCLS)
      ws.update_cell(row,6,dayOpen)
      ws.update_cell(row,7,upperRange)
      ws.update_cell(row,8,lowerRange)
      ws.update_cell(row,9,dayOpenOrClose)
      ws.update_cell(row,10,volume)
      ws.update_cell(row,4,"OPEN or CLOSED")
      ws.update_cell(row,17,yearHigh)
      ws.update_cell(row,18,yearLow)
      print("no data found")
      return
  
  if market:
    print("market",market)
    ws.update_cell(row,8,market)
    # date=wd.find_element_by_xpath("/html/body/div[4]/div[2]/div[3]/div/div[1]/span/bg-quote").text
    # print(date)
    value=wd.find_element_by_xpath("//*[@id='quote-header-info']/div[3]/div[1]/p/span[1]").text
    afterOrPre=wd.find_element_by_xpath("//*[@id='quote-header-info']/div[3]/div[1]/p/span[3]/span").text
    print("Value",value)
    prvCLS=wd.find_element_by_xpath("//*[@id='quote-header-info']/div[3]/div[1]/p/span[1]").text
    print("PVRCLS",prvCLS)    
    # volume=wd.find_element_by_xpath("/html/body/div[5]/div[2]/div[5]/mw-rangebar[1]/div[1]/span[1]").text
    volume=wd.find_element_by_xpath("//*[@id='quote-summary']/div[1]/table/tbody/tr[7]/td[2]/span").text
    print("Volume",volume)
    range=wd.find_element_by_xpath("//*[@id='quote-summary']/div[1]/table/tbody/tr[5]/td[2]").text
    print("RANGE",range)
    # dayVol=wd.find_element_by_xpath("/html/body/div[4]/div[6]/div[1]/div[1]/div/ul/li[16]/span[1]").text
    dayOpenOrClose=wd.find_element_by_xpath("//*[@id='quote-header-info']/div[3]/div[1]/div/span[1]").text
    print("dayOpenOrClose",dayOpenOrClose)
    openOrClose=wd.find_element_by_xpath("//*[@id='quote-market-notice']/span").text
    print("openOrClose",openOrClose)
    # dayClose=wd.find_element_by_xpath("/html/body/div[4]/div[2]/div[3]/div/div[4]/table/tbody/tr/td[1]").text
    dayOpen=wd.find_element_by_xpath("//*[@id='quote-summary']/div[1]/table/tbody/tr[2]/td[2]/span").text
    print("dayOpen",dayOpen)
    yearly=wd.find_element_by_xpath("/html/body/div[1]/div/div/div[1]/div/div[3]/div[1]/div/div[1]/div/div/div/div[2]/div[1]/table/tbody/tr[6]/td[2]").text
    print("yearly",yearly)
    yearHigh=yearly.split("-")[1]
    print("yearHigh",yearHigh)
    yearLow=yearly.split("-")[0]
    print("yearLow",yearLow)
    upperRange=range.split("-")[1]
    print("Upper Range",upperRange)
    lowerRange=range.split("-")[0]
    print("Lower Range",lowerRange)
    # day=date.split(" ")[1].split(",")[0]
    # month=date.split(" ")[0]
    # year=date.split(" ")[2]
    timetime=wd.find_element_by_xpath("/html/body/div[1]/div/div/div[1]/div/div[2]/div/div/div[4]/div/div/div/div[3]/div[1]/p/span[3]").text
    print("timetime",timetime)
    time=timetime.split(":")[1]+":"+timetime.split(":")[2]
    print("time",time)
    # time=date.split(" ")[3]+date.split(" ")[4]   
    ws.update_cell(row,1,datetoday)
    ws.update_cell(row,2,exchange)
    ws.update_cell(row,3,symbol)
    ws.update_cell(row,4,afterOrPre)
    ws.update_cell(row,5,prvCLS)
    ws.update_cell(row,6,dayOpen)
    ws.update_cell(row,7,upperRange)
    ws.update_cell(row,8,lowerRange)
    ws.update_cell(row,9,dayOpenOrClose)
    ws.update_cell(row,10,volume)
    if  afterOrPre.find("Pre")!=-1:
      print("pre data is writing")
      ws.update_cell(row,11,value)
      ws.update_cell(row,12,time)
      # ws.update_cell(row,1,volume)
    # elif data[row][11]:
      print('has pre value')
    # else:
      # ws.update_cell(row,11,"No activity rigth now")
    # print("market.find()",market.find("After"))
    if afterOrPre.find("After")!=-1:
      print("after data is writing")
      ws.update_cell(row,14,value)
      ws.update_cell(row,15,time)
      # ws.update_cell(row,17,volume)
    # elif data[row][15]:
      # print(len(data))
      # print("has post value")
    # else:
      # ws.update_cell(row,14,"No activity rigth now")

    ws.update_cell(row,17,yearHigh)
    ws.update_cell(row,18,yearLow)
  
  # elif market=="OPEN":
  #   ws.update_cell(row,8,market)
  

  # else:
  #   ws.update_cell(row,8,market)
  #   print("Market is closed right now")

def runBatch(s,e,l):
  threadList=[]
  for row in symbols_data[s:e]:
    t=threading.Thread(target=getMarketData,args=(row[1],row[0],l+2,wd,))
    l=l+1
    threadList.append(t)
    t.start()
  for j in threadList:
    j.join()
    print("****************************finished")
  return l


# for i in range(0,len(symbols_data),100):
#   print(i,i+10)
#   print(lengthWs)
#   lengthWs=runBatch(i,i+10,lengthWs)
#   print(lengthWs)

# runBatch(0,2,lengthWs)
# runBatch(1,2,lengthWs)

# p1 = multiprocessing.Process(target=getMarketData, args=(symbols_data[0][1],symbols_data[0][0],lengthWs+1+1,))
# p2 = multiprocessing.Process(target=getMarketData, args=(symbols_data[1][1],symbols_data[1][0],lengthWs+1+1+1, ))

# p1.start()
# p2.start()

# p1.join()
# p2.join()

# print('Done')

for i in range(0,len(symbols_data)-27):
#   # if i==0:
#   #  getAndWrite(symbols_data[i][1],symbols_data[i][0],lengthWs+1+1) 
#   # else:
  getMarketData(symbols_data[i][1],symbols_data[i][0],lengthWs+1+1)
  lengthWs=lengthWs+1

# /html/body/div[1]/div/div/div/form/div[2]/div[2]/button

# %%
# ws=wb.worksheet("mywork")
# data=ws.get_all_values()
# length=len(data)
# lengthWs=0
# symbols_ws=wb.worksheet("listofSymbols")
# symbols_data=symbols_ws.get_all_values()
# datetoday = datetime.now().strftime("%Y-%m-%d")
# for i in range(length):
#   if data[i][0]=='' or data[i][0]==datetoday:
#     lengthWs=i
#     break
# print(lengthWs)
# ws.update_cell(lengthWs+1,1,datetoday)
# # lengthWs=lengthWs

# def getMarketData(symbol,exchange,row):
#   import time
#   marketUrl='https://www.marketwatch.com/investing/stock/'+symbol
#   print(marketUrl)
#   wd.get(marketUrl)
#   time.sleep(1)
#   wd.save_screenshot(symbol+".png")
#   market=wd.find_element_by_xpath("/html/body/div[4]/div[2]/div[3]/div/small/div").text
#   if market!="CLOSED" and (market=="PREMARKET" or market =="AFTERMARKET"):

#     print(market)
#     ws.update_cell(row,8,market)
#     date=wd.find_element_by_xpath("/html/body/div[4]/div[2]/div[3]/div/div[1]/span/bg-quote").text
#     print(date)
#     try:
#       value=wd.find_element_by_xpath("/html/body/div[4]/div[2]/div[3]/div/div[2]/h3/span").text
#     except:
#       value=wd.find_element_by_xpath("/html/body/div[4]/div[2]/div[3]/div/div[2]/h3/bg-quote").text
#     print(value)
#     # volume=wd.find_element_by_xpath("/html/body/div[5]/div[2]/div[5]/mw-rangebar[1]/div[1]/span[1]").text
#     volume=wd.find_element_by_xpath("/html/body/div[5]/div[2]/div[5]/mw-rangebar[1]/div[1]/span[1]").text
#     print(volume)
#     range=wd.find_element_by_xpath("/html/body/div[4]/div[6]/div[1]/div[1]/div/ul/li[2]/span[1]").text
#     print(range)
#     dayVol=wd.find_element_by_xpath("/html/body/div[4]/div[6]/div[1]/div[1]/div/ul/li[16]/span[1]").text
    
#     dayClose=wd.find_element_by_xpath("/html/body/div[4]/div[2]/div[3]/div/div[4]/table/tbody/tr/td[1]").text
#     dayOpen=wd.find_element_by_xpath("/html/body/div[4]/div[6]/div[1]/div[1]/div/ul/li[1]/span[1]").text
#     yearHigh=wd.find_element_by_xpath("/html/body/div[4]/div[6]/div[1]/div[1]/div/ul/li[3]/span[1]").text
#     print(yearly)
#     yearHigh=yearHigh.split("-")[1]
#     yearLow=yearHigh.split("-")[0]
#     upperRange=range.split("-")[1]
#     lowerRange=range.split("-")[0]

#     day=date.split(" ")[1].split(",")[0]
#     month=date.split(" ")[0]
#     year=date.split(" ")[2]
#     time=date.split(" ")[3]+date.split(" ")[4]
    


    
#     ws.update_cell(row,1,datetoday)
    
#     ws.update_cell(row,2,exchange)
#     ws.update_cell(row,3,symbol)
#     # ws.update_cell(row,4,symbol) this needs to checked PRVCLS
#     ws.update_cell(row,5,dayOpen)
#     ws.update_cell(row,6,upperRange)
#     ws.update_cell(row,7,lowerRange)
#     ws.update_cell(row,8,dayClose)
#     ws.update_cell(row,9,dayVol)
#     if(data[row][10]=="" and market=="PREMARKET"):
#       ws.update_cell(row,10,value)
#       ws.update_cell(row,11,time)
#       ws.update_cell(row,12,volume)
#     else:
#       ws.update_cell(row,11,"No activity rigth now")

#     if(data[row][13]=="" and market=="AFTERMARKET"):
#       ws.update_cell(row,13,value)
#       ws.update_cell(row,14,time)
#       ws.update_cell(row,15,volume)
#     else:
#       ws.update_cell(row,14,"No activity rigth now")

#     ws.update_cell(row,16,yearHigh)
#     ws.update_cell(row,17,yearLow)
  
#   elif market=="OPEN":
#     ws.update_cell(row,8,market)
  

#   else:
#     ws.update_cell(row,8,market)
#     print("Market is closed right now")


# for i in range(0,len(symbols_data)):
#   # if i==0:
#   #  getAndWrite(symbols_data[i][1],symbols_data[i][0],lengthWs+1+1) 
#   # else:
#   getMarketData(symbols_data[i][1],symbols_data[i][0],lengthWs+1+1)
#   lengthWs=lengthWs+1

# %%
# import time
# ws=wb.worksheet("mywork")
# data=ws.get_all_values()
# length=len(data)
# lengthWs=0
# symbols_ws=wb.worksheet("listofSymbols")
# symbols_data=symbols_ws.get_all_values()
# for i in range(length):
#   if data[i][0]=='':
#     lengthWs=i
#     break
# print(lengthWs)
# datetoday = datetime.now().strftime("%Y-%m-%d")
# ws.update_cell(lengthWs+1,1,datetoday)
# lengthWs=lengthWs

# def afterMarket(symbol,exchange,row):
#   premarketurlfirst='https://finance.yahoo.com/quotes/'
#   premarketurlsecond=',PREMARKET/view/v1'
#   premarket_url=premarketurlfirst+symbol+premarketurlsecond
#   print(premarket_url)
#   aftermarketurlfirst='https://finance.yahoo.com/quotes/'
#   aftermarketurlsecond=',AFTERMARKET/view/v1'
#   aftermarket_url=aftermarketurlfirst+symbol+aftermarketurlsecond
  
#   wd.get(premarket_url)
#   time.sleep(1)
#   try:
#     df=pd.read_html(wd.page_source)
#   except:
#     wd.save_screenshot("error.png")
#     print("Please try again after 5 minuts")
#     return
#   preval=df[0].values.tolist()[0][1]
#   prevol=df[0].values.tolist()[0][6]
  
#   wd.get(aftermarket_url)
#   time.sleep(1)
#   try:
#     df=pd.read_html(wd.page_source)
#   except:
#     wd.save_screenshot("error.png")
#     print("Please try again after 5 minuts")
#     return
#   afterval=df[0].values.tolist()[0][1]
#   aftervol=df[0].values.tolist()[0][6]
  
  
#   ws.update_cell(row,1,datetoday)
  
#   ws.update_cell(row,5,exchange)
#   ws.update_cell(row,6,symbol)
#   ws.update_cell(row,14,preval)
#   ws.update_cell(row,16,prevol)
#   ws.update_cell(row,17,afterval)
#   ws.update_cell(row,19,aftervol)


# def getAndWrite(symbol,exchange,row):
#   premarketurlfirst='https://finance.yahoo.com/quotes/'
#   premarketurlsecond=',PREMARKET/view/v1'
#   premarket_url=premarketurlfirst+symbol+premarketurlsecond
#   print(premarket_url)
#   aftermarketurlfirst='https://finance.yahoo.com/quotes/'
#   aftermarketurlsecond=',AFTERMARKET/view/v1'
#   aftermarket_url=aftermarketurlfirst+symbol+aftermarketurlsecond
  
#   wd.get(premarket_url)
#   time.sleep(1)
#   try:
#     df=pd.read_html(wd.page_source)
#   except:
#     wd.save_screenshot("error.png")
#     print("Please try again after 5 minuts")
#     return
#   preval=df[0].values.tolist()[0][1]
#   prevol=df[0].values.tolist()[0][6]
  
#   wd.get(aftermarket_url)
#   time.sleep(1)
#   try:
#     df=pd.read_html(wd.page_source)
#   except:
#     wd.save_screenshot("error.png")
#     print("Please try again after 5 minuts")
#     return
#   afterval=df[0].values.tolist()[0][1]
#   aftervol=df[0].values.tolist()[0][6]
  
  
#   ws.update_cell(row,1,datetoday)
  
#   ws.update_cell(row,5,exchange)
#   ws.update_cell(row,6,symbol)
#   ws.update_cell(row,14,preval)
#   ws.update_cell(row,16,prevol)
#   ws.update_cell(row,17,afterval)
#   ws.update_cell(row,19,aftervol)


# for i in range(0,len(symbols_data)):
#   # if i==0:
#   #  getAndWrite(symbols_data[i][1],symbols_data[i][0],lengthWs+1+1) 
#   # else:
#   getAndWrite(symbols_data[i][1],symbols_data[i][0],lengthWs+1+1)
#   lengthWs=lengthWs+1

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# # get_all_values gives a list of rows.
# rows = ws.get_all_values()
# # print(rows)

# # Convert to a DataFrame and render.
# # import pandas as pd
# df=pd.DataFrame.from_records(rows[5:],columns=rows[0])
# print(df)

# %%
# wd.get("https://www.marketwatch.com/investing/stock/amzn")

# market=wd.find_element_by_xpath("/html/body/div[4]/div[2]/div[3]/div/small/div").text
# date=wd.find_element_by_xpath("/html/body/div[4]/div[2]/div[3]/div/div[1]/span/bg-quote").text
# value=wd.find_element_by_xpath("/html/body/div[4]/div[2]/div[3]/div/div[2]/h3/bg-quote").text
# volume=wd.find_element_by_xpath("/html/body/div[4]/div[2]/div[3]/div/div[3]/span[2]/bg-quote").text
# range=wd.find_element_by_xpath("/html/body/div[4]/div[6]/div[1]/div[1]/div/ul/li[2]/span[1]").text
# dayVol=wd.find_element_by_xpath("/html/body/div[4]/div[6]/div[1]/div[1]/div/ul/li[16]/span[1]").text
# dayClose=wd.find_element_by_xpath("/html/body/div[4]/div[2]/div[3]/div/div[4]/table/tbody/tr/td[1]").text
# dayOpen=wd.find_element_by_xpath("/html/body/div[4]/div[6]/div[1]/div[1]/div/ul/li[1]/span[1]").text
# yearHigh=wd.find_element_by_xpath("/html/body/div[4]/div[6]/div[1]/div[1]/div/ul/li[3]/span[1]").text.split("-")[1]
# yearLow=wd.find_element_by_xpath("/html/body/div[4]/div[6]/div[1]/div[1]/div/ul/li[3]/span[1]").text.split("-")[0]

# upperRange=range.split("-")[1]
# lowerRange=range.split("-")[0]

# day=date.split(" ")[1].split(",")[0]
# month=date.split(" ")[0]
# year=date.split(" ")[2]
# time=date.split(" ")[3]+date.split(" ")[4]
# print(day)
# print(month)
# print(year)
# print(market)
# print(value)
# print(volume)
# print(time)

# # wd.save_screenshot("ss.png")

# %%
import time
import pandas as pd
wd.get("https://finance.yahoo.com/quote/AMZN/")
time.sleep(1)
html=wd.page_source
df=pd.read_html(html)

# %%
print(len(df))
print(df[2])
# market=wd.find_element_by_xpath("//*[@id='quote-header-info']/div[3]/div[1]/p/span[3]/span").text
# print(market)  
# wd.save_screenshot("check.png")
